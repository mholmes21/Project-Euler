# %%
# Open the file
f = open("p099_base_exp.txt", "r")

# %%
# Pre-processing: check the number of digits in each line
biggest_digits = -1
count = 0
digits = list()
for line in f:
    a = int(line.split(",")[0])
    b = int(line.split(",")[1])
    
    d = math.floor(b * math.log10(a)) + 1
    
    digits.append(d)

# Find the line number of the maximum number of digits
#indices = [i for i, x in enumerate(digits) if x == max(digits)]
print(indices)
#digits.sort()
#print(digits)
#print(max(digits))
# Out:
# [171, 708]

# %%
# Loop through file, keeping track of the max & line number
i = 1
biggest = -1
biggest_line = -1

f2 = open("p099_base_exp.txt", "r")
for line in f2:
    b = int(line.split(",")[0])
    e = int(line.split(",")[1])
    
    d = int(b * math.log10(a)) + 1
    #print("(Line,d):", "(" , i , "," , d, ")")
    
    if len(str(d)) == 7: 
        tmp = b**e
        #print("Max digits hit!")
        if tmp > biggest:
            biggest = tmp
            biggest_line = i
            print("Update on line:", i)
    print("Percent Complete:", float(i/10))
    print()
    i += 1
# Out:
# Update on line: 1
# Percent Complete: 0.1
#
# Update on line: 2
# Percent Complete: 0.2
#
# Percent Complete: 0.3
#
# Update on line: 4
# Percent Complete: 0.4
#
# Update on line: 5
# Percent Complete: 0.5
#
# Update on line: 6
# Percent Complete: 0.6
#
# Percent Complete: 0.7
#
# Update on line: 8
# Percent Complete: 0.8
#
# Percent Complete: 0.9
#
# Percent Complete: 1.0
#
# Percent Complete: 1.1
#
# Percent Complete: 1.2
#
# Percent Complete: 1.3
#
# Percent Complete: 1.4
#
# Percent Complete: 1.5
#
# Percent Complete: 1.6
#
# Percent Complete: 1.7
#
# Percent Complete: 1.8
#
# Percent Complete: 1.9
#
# Percent Complete: 2.0
#
# Update on line: 21
# Percent Complete: 2.1
#
# Percent Complete: 2.2
#
# Percent Complete: 2.3
#
# Percent Complete: 2.4
#
# Percent Complete: 2.5
#
# Percent Complete: 2.6
#
# Percent Complete: 2.7
#
# Percent Complete: 2.8
#
# Percent Complete: 2.9
#
# Percent Complete: 3.0
#
# Percent Complete: 3.1
#
# Percent Complete: 3.2
#
# Percent Complete: 3.3
#
# ...

# %%
print("Biggest thing is on line", biggest_line)
# Out:
# Biggest thing is on line 709
